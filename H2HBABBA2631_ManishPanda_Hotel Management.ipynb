# %% [markdown]
# I am creating the main hotelmanagement class which has only one object and through the only object i am inputing all the data and storing them in list of dictionaries.
#
# I have given the total rooms as 10. Can be changed as needed.

# %% [markdown]
# First there is the **home menu with 4 options**
#
# ->**1st** is the **Booking option** by choosing this option we can see the no of available and reserved rooms
#
# ->then we can enter the customer details which will be stored and will be printed again for user confirmation
#
# ->**2nd** is **Enquiry option** it again has **3 options for searching**
#
# ->**1 is searching with the customer name**, this option displays all details associated with the enter customer name if he has booked any rooms
#
# ->**2 is searching with room no**, this option displays all details associated with the customer who has booked the room no that is entered.
#
# ->**3 is to check availability of rooms**, this options displays a list of all available rooms
#
# ->then going back to the home menu theres the **3rd option **which is** Edit menu**
#
# ->this menu has **2 options** that is **Edit and Delete**
#
# ->In **edit option** there are again **4 different options** that is to edit customer name or customer phone number of if customer wants to book more rooms or edit their stay duration.
#
# ->now last is the Exit option to exit the menu.
#
# (Thankyou and sorry for the long description😅.)
#
# --Manish Panda --H2HBABBA2631 --14255

# %%
#creating the class containing all the methods and fuctionalities
class hotelmanagement:
  def __init__(self,totalrooms):
      #creating a list for storing all customer details in dictionaries
      #another list for storing details for all availabe rooms and one for storing reserved rooms
      self.rooms=[]
      self.roomsA=list(range(1,totalrooms+1))
      self.roomsR=[]

  #defining a method for booking room by providing all customer details
  def booking(self):
      #checking if there are any available rooms
      if not self.roomsA:
        print("All rooms are booked at the moment.")
      else:
        print("\nRooms Available: ",len(self.roomsA))
        print("Rooms Reserved: ",len(self.roomsR))              #printing no of available and reserved rooms
        name=input("\nEnter your Fullname:")
        phone=int(input("Enter your phone number:"))
        nor=int(input("Enter your number of rooms you want to book:"))
        if len(self.roomsA)>=nor:                               #checking if rooms available are more or equal as required by customer
          sd=input("Enter your stay duration:")
          rno=[]
          for i in range(nor):
            rno.append(self.roomsA.pop(0))
          self.roomsR+=rno
          tempRoom={"roomno":rno,"name":name,"phone":phone,"numberofrooms":nor,"stayduration":sd}
          self.rooms.append(tempRoom)
          self.display(tempRoom)
        else:
          print("The number of requested rooms are booked at the moment.")
        
  #defining a method for displaying customer details
  def display(self,tempRoom):
      print()
      print ("Customer details:")
      print ("Customer name: ",tempRoom['name'])
      print ("Customer phone number: ",tempRoom['phone'])
      print ("Total number of rooms booked: ",tempRoom['numberofrooms'])
      print ("Total Stay Duration: ",tempRoom['stayduration'])
      print ("Room no.",tempRoom['roomno'])
      print()
      
  #defing a method for the enquiry option/menu
  def enquiry(self):
      print("\nEnquiry Menu")
      print("1.Search with Customer Name. ")
      print("2.Search with Room No. ")
      print("3.Check Room Availability ")
      c=int(input("\nEnter choice of enquiry: "))
      if c==1:                                                  #it displays all customer details with the customer name
            if not self.rooms:
              print("All rooms are vacant.")
            else:
              s=input("Enter Customer Name: ")
              res=list(filter(lambda room: room['name'] == s, self.rooms))
              if not res:
                print("Customer Name not found.")
              else:
                for x in res:
                  self.display(x)
              

      elif c==2:                                              #it displays all customer details who has reserved the given room no
            if not self.rooms:
              print("All rooms are vacant.")
            else:
              s=int(input("Enter Room No: "))  
              res=list(filter(lambda room: s in room['roomno']  , self.rooms))
              if not res:
                print("Room No has not been booked.")
              else:
                self.display(res[0])
      elif c==3:                                        #it displays all available rooms
             print("\nRooms Available: ",self.roomsA) 
      else:
        print("Invalid choice. Please try again.")

  #defining the method for the edit menu
  def edit(self):
      if not self.rooms:
                print("All rooms are vacant.")
      else:
        print("\nEdit Menu: ")
        s=int(input("Enter Room No: "))  
        res=next((room for room in self.rooms if s in room["roomno"] ),None)
        if res==None:
          print("Room No has not been booked.")
        else:
          self.display(res)                                 
          print("Select from given options:-")
          print("1.Edit Customer Name")
          print("2.Edit Customer Phone Number")
          print("3.Add Room")
          print("4.Edit Stay Duration")
          f=int(input("Enter choice: "))
          if f==1:                                                              #to edit the customer name
              cname=input("Enter new Name: ")
              res['name']=cname
          elif f==2:                                                            #to edit the customer phone number
              cphone=int(input("Enter new Phone Number: "))
              res['phone']=cphone
          elif f==3:                                                            #to add more add to existing customer
              crooms=int(input("Enter number of rooms to add: "))
              if len(self.roomsA)>=crooms:
                  rno=[]
                  for i in range(crooms):
                    rno.append(self.roomsA.pop(0))
                    self.roomsR+=rno
                  res['roomno']+=rno
              else:
                  print("The number of requested rooms are booked at the moment.")
          elif f==4:                                                            #to edit the stay duration of existing customer
              cdur=input("Enter new Stay Duration: ")
              res['stayduration']=cdur
          else:
            print("Invalid choice. Please try again.")

  #defining the method for the delete option in the edit menu
  #clears/deletes room details and makes it available again one at a time
  def delete(self):
      if not self.rooms:
                print("All rooms are vacant.")
      else:
        s=int(input("Enter Room No to vacate: "))  
        res=next((room for room in self.rooms if s in room["roomno"] ),None)
        if res==None:
          print("Room No has not been booked.")
        else:
          crooms=res['roomno']
          res['roomno'].remove(s)
          if len(crooms)>1:
            self.roomsR.remove(s)
            self.roomsA.append(s)
            self.roomsA.sort()
          else:
            self.rooms=list(filter(lambda room: s not in room['roomno']  , self.rooms))
            for i in crooms:
              self.roomsR.remove(i)
              self.roomsA.append(i)
            self.roomsA.sort()

# %%
def main():
    a=hotelmanagement(10)
    while(True):
      print("\nHome Menu")
      print("1.Booking")
      print("2.Enquiry")
      print("3.Edit Menu")
      print("4.Exit")
      b=int(input("\nEnter the number of your choice:"))
      if b==1:
              a.booking()
      elif b==2:
              a.enquiry()
      elif b==3:
              print("1.Edit")
              print("2.Delete")
              z=int(input("\nEnter the number of your choice:"))
              if z==1:
                a.edit()
              elif z==2:
                a.delete()
              else:
                 print("Invalid choice. Please try again.")
      elif b==4:
              break
      else:
              print("Invalid choice. Please try again.")

main()
# Out:
# Home Menu
# 1.Booking
# 2.Enquiry
# 3.Edit Menu
# 4.Exit
#
# Enter the number of your choice:1
#
# Rooms Available:  10
# Rooms Reserved:  0
#
# Enter your Fullname:shamik
# Enter your phone number:12121212
# Enter your number of rooms you want to book:3
# Enter your stay duration:6
#
# Customer details:
# Customer name:  shamik
# Customer phone number:  12121212
# Total number of rooms booked:  3
# Total Stay Duration:  6
# Room no. [1, 2, 3]
#
#
# Home Menu
# 1.Booking
# 2.Enquiry
# 3.Edit Menu
# 4.Exit
#
# Enter the number of your choice:1
#
# Rooms Available:  7
# Rooms Reserved:  3
#
# Enter your Fullname:shamik
# Enter your phone number:3344444
# Enter your number of rooms you want to book:2
# Enter your stay duration:1
#
# Customer details:
# Customer name:  shamik
# Customer phone number:  3344444
# Total number of rooms booked:  2
# Total Stay Duration:  1
# Room no. [4, 5]
#
#
# Home Menu
# 1.Booking
# 2.Enquiry
# 3.Edit Menu
# 4.Exit
#
# Enter the number of your choice:1
# ...
